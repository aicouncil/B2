# %%
cats = '/kaggle/input/dog-and-cat-classification-dataset/PetImages/Cat'
dogs = '/kaggle/input/dog-and-cat-classification-dataset/PetImages/Dog'

# %% [markdown]
# **Read all the images and store into an array - features**

# %%
import cv2
import os
from tqdm import tqdm

features = []
labels = []

for img_name in tqdm(os.listdir(cats)):
    #print(os.path.join(cats, img_name))
    img = cv2.imread(os.path.join(cats, img_name))

    #Skip if img not loaded
    if img is None:
        print(f"Skipping file: {img_name}" )
        continue

    labels.append(0)
        
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img = cv2.resize(img, (50,50))
    features.append(img)


for img_name in tqdm(os.listdir(dogs)):
    #print(os.path.join(cats, img_name))
    img = cv2.imread(os.path.join(dogs, img_name))

    #Skip if img not loaded
    if img is None:
        print(f"Skipping file: {img_name}" )
        continue

    labels.append(1)
        
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img = cv2.resize(img, (50,50))
    features.append(img)
# Out:
#   1%|          | 150/12499 [00:00<01:07, 182.78it/s]Corrupt JPEG data: 239 extraneous bytes before marker 0xd9
#   7%|▋         | 849/12499 [00:05<01:06, 174.56it/s]
# Skipping file: 4833.jpg
#   8%|▊         | 967/12499 [00:06<01:23, 138.19it/s]
# Skipping file: 850.jpg
#  11%|█         | 1341/12499 [00:07<00:50, 221.60it/s]
# Skipping file: 8470.jpg
#  13%|█▎        | 1625/12499 [00:09<00:51, 210.64it/s]Corrupt JPEG data: 99 extraneous bytes before marker 0xd9
#  22%|██▏       | 2788/12499 [00:15<00:43, 225.58it/s]
# Skipping file: 11210.jpg
#  27%|██▋       | 3401/12499 [00:18<00:49, 182.93it/s]
# Skipping file: 660.jpg
#  32%|███▏      | 4017/12499 [00:21<00:41, 206.08it/s]
# Skipping file: 140.jpg
#  33%|███▎      | 4106/12499 [00:22<00:41, 199.89it/s]
# Skipping file: 10820.jpg
#  39%|███▉      | 4847/12499 [00:26<00:36, 209.94it/s]
# Skipping file: 10501.jpg
#  43%|████▎     | 5327/12499 [00:28<00:34, 210.37it/s]
# Skipping file: 9171.jpg
#  43%|████▎     | 5434/12499 [00:29<00:37, 186.19it/s]Corrupt JPEG data: 214 extraneous bytes before marker 0xd9
#  44%|████▍     | 5529/12499 [00:29<00:37, 188.04it/s]
# Skipping file: 9778.jpg
#  48%|████▊     | 6044/12499 [00:32<00:31, 202.06it/s]Corrupt JPEG data: 128 extraneous bytes before marker 0xd9
#  54%|█████▎    | 6697/12499 [00:35<00:27, 208.65it/s]
# Skipping file: 2663.jpg
#  62%|██████▏   | 7707/12499 [00:40<00:23, 201.53it/s]
# Skipping file: 11935.jpg
#  65%|██████▌   | 8172/12499 [00:42<00:19, 227.06it/s]
# Skipping file: 10125.jpg
#  66%|██████▌   | 8264/12499 [00:43<00:22, 191.44it/s]
# Skipping file: 11874.jpg
# Skipping file: 936.jpg
#  66%|██████▋   | 8304/12499 [00:43<00:23, 178.08it/s]
# Skipping file: 5553.jpg
#  68%|██████▊   | 8554/12499 [00:44<00:18, 217.45it/s]
# Skipping file: 7978.jpg
#  69%|██████▉   | 8635/12499 [00:45<00:25, 151.23it/s]
# Skipping file: 3491.jpg
#  70%|███████   | 8783/12499 [00:45<00:19, 189.12it/s]
# Skipping file: 3300.jpg
#  76%|███████▋  | 9540/12499 [00:49<00:15, 186.98it/s]Corrupt JPEG data: 1153 extraneous bytes before marker 0xd9
#  80%|████████  | 10042/12499 [00:52<00:11, 215.67it/s]
# Skipping file: 7968.jpg
#  83%|████████▎ | 10348/12499 [00:54<00:12, 172.39it/s]
# Skipping file: 11565.jpg
#  83%|████████▎ | 10427/12499 [00:54<00:12, 171.19it/s]
# Skipping file: 10404.jpg
#  91%|█████████▏| 11407/12499 [00:59<00:06, 178.41it/s]
# Skipping file: 9565.jpg
# 100%|██████████| 12499/12499 [01:05<00:00, 190.17it/s]
#   2%|▏         | 255/12499 [00:01<00:58, 208.48it/s]
# Skipping file: 6059.jpg
# Skipping file: 11849.jpg
#  11%|█         | 1371/12499 [00:06<00:55, 198.71it/s]
# Skipping file: 3288.jpg
# Skipping file: 6238.jpg
#  11%|█▏        | 1411/12499 [00:07<01:05, 170.55it/s]Corrupt JPEG data: 226 extraneous bytes before marker 0xd9
#  15%|█▍        | 1813/12499 [00:09<00:45, 236.88it/s]
# Skipping file: 2688.jpg
#  20%|██        | 2543/12499 [00:13<00:55, 178.52it/s]Corrupt JPEG data: 65 extraneous bytes before marker 0xd9
#  24%|██▍       | 3009/12499 [00:15<00:41, 228.98it/s]
# Skipping file: 7112.jpg
#  25%|██▌       | 3160/12499 [00:16<01:16, 121.99it/s]
# Skipping file: 8730.jpg
#  30%|███       | 3794/12499 [00:20<00:52, 166.47it/s]
# Skipping file: 7133.jpg
#  31%|███       | 3892/12499 [00:20<00:45, 190.37it/s]Warning: unknown JFIF revision number 0.00
#  35%|███▍      | 4316/12499 [00:22<00:31, 262.24it/s]
# Skipping file: 11853.jpg
#  41%|████      | 5096/12499 [00:28<01:04, 115.36it/s]
# Skipping file: 7969.jpg
#  44%|████▍     | 5477/12499 [00:32<01:23, 83.82it/s]
# Skipping file: 7459.jpg
#  46%|████▌     | 5777/12499 [00:35<00:57, 117.88it/s]
# Skipping file: 10747.jpg
#  49%|████▉     | 6173/12499 [00:39<01:02, 101.15it/s]Corrupt JPEG data: 254 extraneous bytes before marker 0xd9
#  51%|█████     | 6376/12499 [00:41<00:53, 114.33it/s]
# Skipping file: 6718.jpg
#  52%|█████▏    | 6471/12499 [00:42<00:57, 104.10it/s]
# Skipping file: 2877.jpg
#  53%|█████▎    | 6579/12499 [00:43<00:56, 104.30it/s]
# Skipping file: 3136.jpg
#  54%|█████▎    | 6695/12499 [00:44<00:56, 101.92it/s]Corrupt JPEG data: 1403 extraneous bytes before marker 0xd9
#  59%|█████▊    | 7328/12499 [00:49<00:18, 277.09it/s]Corrupt JPEG data: 162 extraneous bytes before marker 0xd9
#  59%|█████▉    | 7356/12499 [00:49<00:18, 276.61it/s]Corrupt JPEG data: 2230 extraneous bytes before marker 0xd9
#  61%|██████▏   | 7681/12499 [00:50<00:16, 284.21it/s]
# Skipping file: 11675.jpg
#  65%|██████▍   | 8097/12499 [00:51<00:15, 287.01it/s]
# Skipping file: 4367.jpg
#  66%|██████▋   | 8300/12499 [00:52<00:15, 270.46it/s]
# Skipping file: 5604.jpg
#  70%|███████   | 8775/12499 [00:54<00:13, 280.52it/s]
# Skipping file: 9188.jpg
#  74%|███████▎  | 9200/12499 [00:55<00:11, 297.27it/s]
# Skipping file: 3588.jpg
#  75%|███████▌  | 9404/12499 [00:56<00:11, 279.47it/s]
# Skipping file: 11410.jpg
#  76%|███████▌  | 9522/12499 [00:56<00:10, 274.85it/s]
# Skipping file: 1308.jpg
#  79%|███████▊  | 9815/12499 [00:57<00:09, 286.13it/s]
# Skipping file: 10158.jpg
#  82%|████████▏ | 10245/12499 [00:59<00:07, 301.07it/s]
# Skipping file: 2384.jpg
#  87%|████████▋ | 10831/12499 [01:01<00:05, 295.43it/s]Corrupt JPEG data: 399 extraneous bytes before marker 0xd9
#  92%|█████████▏| 11528/12499 [01:03<00:03, 299.90it/s]
# Skipping file: 1866.jpg
#  93%|█████████▎| 11683/12499 [01:04<00:02, 303.02it/s]
# Skipping file: 7369.jpg
#  94%|█████████▍| 11776/12499 [01:04<00:02, 300.49it/s]
# Skipping file: 10797.jpg
#  96%|█████████▌| 11957/12499 [01:05<00:01, 291.44it/s]
# Skipping file: 10401.jpg
#  97%|█████████▋| 12078/12499 [01:05<00:01, 294.69it/s]
# Skipping file: 5736.jpg
# 100%|██████████| 12499/12499 [01:07<00:00, 186.32it/s]

# %%
import numpy as np
X = np.array(features)
y = np.array(labels)

# %%
X.shape
# Out:
# (24946, 50, 50)

# %%
y.shape
# Out:
# (24946,)

# %%
from keras import models,layers

model = models.Sequential()

model.add(layers.Conv2D(32 , (3,3) , padding='same', input_shape=(50,50,1)))
model.add(layers.MaxPooling2D(2,2))

model.add(layers.Conv2D(64 , (3,3) , padding='same'))
model.add(layers.MaxPooling2D(2,2))

model.add(layers.Conv2D(64 , (3,3) , padding='same'))
model.add(layers.MaxPooling2D(2,2))

model.add(layers.Conv2D(64 , (3,3) , padding='same'))
model.add(layers.MaxPooling2D(2,2))

model.add(layers.Conv2D(64 , (3,3) , padding='same'))
model.add(layers.MaxPooling2D(2,2))

model.add(layers.Flatten())

model.add(layers.Dense(10))

model.add(layers.Dense(1, activation = 'sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_19 (Conv2D)              │ (None, 50, 50, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_13 (MaxPooling2D) │ (None, 25, 25, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_20 (Conv2D)              │ (None, 25, 25, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_14 (MaxPooling2D) │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_21 (Conv2D)              │ (None, 12, 12, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_15 (MaxPooling2D) │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_22 (Conv2D)              │ (None, 6, 6, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_16 (MaxPooling2D) │ (None, 3, 3, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_23 (Conv2D)              │ (None, 3, 3, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_17 (MaxPooling2D) │ (None, 1, 1, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │           650 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 130,261 (508.83 KB)
#  Trainable params: 130,261 (508.83 KB)
#  Non-trainable params: 0 (0.00 B)
