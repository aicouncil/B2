# %%
from sklearn.datasets import load_iris
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
iris = load_iris()
#iris

# %%
df = pd.DataFrame(iris.data, columns = iris.feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
import seaborn as sns
sns.pairplot(df)

# %% [markdown]
# **Inertia to decide optimum number of clusters**

# %%
inertia = []
K = range(1,11)

for k in K:
  km = KMeans(n_clusters = k)
  km.fit(df)
  inertia.append(km.inertia_)


plt.plot(K , inertia , marker = '*')
plt.xlabel("Number of clusters 'K'")
plt.ylabel("Inertia")
plt.show()

# %% [markdown]
# **Silhoutte scores to decided optimum number of cluster**

# %%
from sklearn.metrics import silhouette_score

for k in range(2,10):
  km = KMeans(n_clusters = k)
  km.fit(df)
  labels = km.predict(df)
  score = silhouette_score(df , labels)
  print(f"k={k} , Silhoutte score = {score}")
# Out:
# k=2 , Silhoutte score = 0.6810461692117462
# k=3 , Silhoutte score = 0.5172630288634874
# k=4 , Silhoutte score = 0.4974551890173751
# k=5 , Silhoutte score = 0.48874888709310566
# k=6 , Silhoutte score = 0.3606308816963118
# k=7 , Silhoutte score = 0.4442004092604926
# k=8 , Silhoutte score = 0.3211433498429425
# k=9 , Silhoutte score = 0.3517514188638907
